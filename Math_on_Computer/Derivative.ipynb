# %%
from sympy import symbols, diff,pprint
from sympy.abc import x
exp=(cos(tan(x)))
result=diff(exp,x)
print("Derivative of:")
pprint(exp)
print("Result=",result)
# Out:
# Derivative of:
# cos(tan(x))
# Result= -(tan(x)**2 + 1)*sin(tan(x))

# %%
from sympy import symbols, diff , pprint
from sympy.abc import *
exp=((x+1)/(x-1))
result=diff(exp,x)
print("Derivative of:")
pprint(exp)
print("Result:")
pprint(result)
# Out:
# derivative of:
# x + 1
# ─────
# x - 1
# result
#   1      x + 1
# ───── - ────────
# x - 1          2
#         (x - 1)

# %%
from sympy import symbols, diff , pprint
from sympy.abc import *
exp=(e**x)
result=diff(exp,x)
print("Derivative of:")
pprint(exp)
print("Result:")
pprint(result)
# Out:
# Derivative of:
#  x
# e
# Result:
#  x
# e ⋅log(e)

# %%
from sympy import symbols, diff , pprint
from sympy.abc import *
exp=(sin(3*x+5))
result=diff(exp,x)
print("Derivative of:")
pprint(exp)
print("Result:")
pprint(result)
# Out:
# Derivative of:
# sin(3⋅x + 5)
# Result:
# 3⋅cos(3⋅x + 5)

# %%
from sympy import symbols, diff , pprint
from sympy.abc import *
exp=((x+1)/(x-1))
result=diff(exp,x)
print("Derivative of:")
pprint(exp)
print("Result:")
pprint(result)
# Out:
# Derivative of:
# x + 1
# ─────
# x - 1
# Result:
#   1      x + 1
# ───── - ────────
# x - 1          2
#         (x - 1)

# %%
from sympy import symbols, diff , pprint
from sympy.abc import *
exp=(e**tan(x))
result=diff(exp,x)
print("Derivative of:")
pprint(exp)
print("Result:\n")
pprint(result)
# Out:
# Derivative of:
#  tan(x)
# e
# Result:
#
#  tan(x) ⎛   2       ⎞
# e      ⋅⎝tan (x) + 1⎠⋅log(e)

# %%
from sympy import symbols, diff , pprint
from sympy.abc import *
x = symbols('x')

exp=(((x+3)*(x+2))/x**2)
result=diff(exp,x)

print("Derivative of:")
pprint(exp)
print("Result:\n")
pprint(result)
# Out:
# Derivative of:
# (x + 2)⋅(x + 3)
# ───────────────
#         2
#        x
# Result:
#
# x + 2   x + 3   2⋅(x + 2)⋅(x + 3)
# ───── + ───── - ─────────────────
#    2       2             3
#   x       x             x

# %%
from sympy import symbols, diff , pprint
from sympy.abc import x


exp=(cos(tan(x)))
result=diff(exp,x)

print("Derivative of:")
pprint(exp)
print("Result:\n")
print(result)
pprint(result)
# Out:
# Derivative of:
# cos(tan(x))
# Result:
#
# -(tan(x)**2 + 1)*sin(tan(x))
#  ⎛   2       ⎞
# -⎝tan (x) + 1⎠⋅sin(tan(x))

# %%
from sympy import symbols,diff,pprint
from sympy.abc import x
exp=(e**x* (sin(x)))
print("derivative of")
pprint(exp)
print(exp)
pprint(result)
# Out:
# derivative of
#  x
# e ⋅sin(x)
# e**x*sin(x)
#  ⎛   2       ⎞
# -⎝tan (x) + 1⎠⋅sin(tan(x))
